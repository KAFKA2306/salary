# %%
import pandas as pd

# %%
df=pd.read_excel(fr'C:\Users\100ca\Documents\PyCode\IR\data\data_j.xls')
df.to_csv(fr'C:\Users\100ca\Documents\PyCode\IR\data\data_j.csv')

# %%
# フィルタリングする値のリスト
categories = [
    'プライム（内国株式）', 'ETF・ETN', 'PRO Market', 'スタンダード（内国株式）',
    'グロース（内国株式）', 'プライム（外国株式）', 'REIT・ベンチャーファンド・カントリーファンド・インフラファンド',
    'スタンダード（外国株式）', 'グロース（外国株式）', '出資証券'
]
categories = [
    'プライム（内国株式）', 'スタンダード（内国株式）',
    'グロース（内国株式）',
]

# '市場・商品区分'列がcategoriesリストに含まれる行をフィルタリング
df = df[df["市場・商品区分"].isin(categories)]

# %%
df.to_csv(fr'C:\Users\100ca\Documents\PyCode\IR\data\data_j_filtered.csv')
df[['コード']].to_csv(fr'C:\Users\100ca\Documents\PyCode\IR\data\tickers.csv')

# %%
df
# Out:
#             日付   コード     銘柄名       市場・商品区分 33業種コード  33業種区分 17業種コード 17業種区分  \
# 0     20240131  1301      極洋    プライム（内国株式）      50  水産・農林業       1     食品
# 17    20240131  1332    ニッスイ    プライム（内国株式）      50  水産・農林業       1     食品
# 18    20240131  1333  マルハニチロ    プライム（内国株式）      50  水産・農林業       1     食品
# 35    20240131  1375  雪国まいたけ    プライム（内国株式）      50  水産・農林業       1     食品
# 36    20240131  1376   カネコ種苗  スタンダード（内国株式）      50  水産・農林業       1     食品
# ...        ...   ...     ...           ...     ...     ...     ...    ...
# 4336  20240131  9993    ヤマザワ  スタンダード（内国株式）    6100     小売業      14     小売
# 4337  20240131  9994     やまや  スタンダード（内国株式）    6100     小売業      14     小売
# 4338  20240131  9995   グローセル    プライム（内国株式）    6050     卸売業      13  商社・卸売
# 4339  20240131  9996   サトー商会  スタンダード（内国株式）    6050     卸売業      13  商社・卸売
# 4340  20240131  9997    ベルーナ    プライム（内国株式）    6100     小売業      14     小売
#
#      規模コード           規模区分
# 0        7  TOPIX Small 2
# ...
