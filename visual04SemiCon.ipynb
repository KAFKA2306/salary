# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text  # adjustTextをインポート

# %%
# CSVファイルからデータを読み込む with 'utf-8' encoding
df = pd.read_csv(fr'C:\Users\100ca\Documents\PyCode\scraping\data\results.csv', encoding='utf-8')

# '情報なし'や'---'などのデータをNaNに変換
df.replace({'情報なし': None, '---': None}, inplace=True)

# 数値データの列をfloat型に変換
numerical_cols = ['salary', 'overtime', 'salary_25_29', 'salary_30_34', 'salary_35_39', 'salary_40_44', 'salary_45_49', 'salary_50_54', 'salary_55_59', 'salary_60_up']

# Replace non-numeric values in these columns with NaN
for col in numerical_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# フォントの設定
plt.rcParams['font.family'] = 'Meiryo'  # 使用するフォント名を指定

# %%
plt.figure(figsize=(10, 20))

# 'salary' 列の欠損値を持つ行を削除し、'salary' の値で降順にソート
df = df.dropna(subset=['salary']).sort_values('salary', ascending=False)

# 水平棒グラフをプロット
sns.barplot(x='salary', y='company', data=df)

plt.title('平均年収 by 会社')
plt.xlabel('平均年収 (万円)')
plt.ylabel('会社')
plt.show()

# %%
plt.figure(figsize=(10, 16))

# データを 'salary_25_29' 列でソートし、上位100件を取得
sorted_df = df.sort_values('salary_25_29', ascending=False).head(100)

# 水平棒グラフをプロット
barplot = sns.barplot(x='salary_25_29', y='company', data=sorted_df)

plt.title('salary_25_29 by 会社')
plt.xlabel('salary_25_29 (万円)')
plt.ylabel('会社')

# 各バーに値をアノテーションとして追加
for p in barplot.patches:
    width = p.get_width()
    plt.text(width + 5,  # アノテーションのx位置
             p.get_y() + p.get_height() / 2,  # アノテーションのy位置
             '{:1.0f}'.format(width),  # アノテーションのテキスト（バーの幅）
             ha='center', va='center')

plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.figure(figsize=(10, 20))
sns.barplot(x='overtime', y='company', data=df.sort_values('overtime', ascending=False).head(100))
plt.title('残業時間 by 会社')
plt.xlabel('残業時間 (時間/月)')
plt.ylabel('会社')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text  # adjustTextをインポート

plt.figure(figsize=(10, 8))

# 残業時間と給与の関係を散布図で表示
scatter = sns.scatterplot(x='overtime', y='salary_25_29', data=df)

texts = []
for i in range(len(df)):
    # 有限値（finite value）であることを確認し、y軸の範囲内にあるデータのみをアノテーションする
    if pd.notnull(df.overtime.iloc[i]) and pd.notnull(df.salary_25_29.iloc[i]):
        text = plt.text(x=df.overtime.iloc[i], y=df.salary_25_29.iloc[i], s=df.company.iloc[i], 
                        fontdict=dict(color='grey',size=5))
        texts.append(text)

plt.title('salary_25_29 by Overtime Hours (半導体)')
plt.xlabel('Overtime Hours')
plt.ylabel('salary_25_29 (x10,000 Yen)')

# テキストのオーバーラップを避ける
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='grey'))

plt.show()

# %%
age_salary_df = df[['company', 'salary_25_29', 'salary_30_34', 'salary_35_39', 'salary_40_44', 'salary_45_49', 'salary_50_54', 'salary_55_59', 'salary_60_up']]

plt.figure(figsize=(12, 10))
sns.heatmap(age_salary_df.set_index('company'), annot=True, fmt=".0f", cmap='coolwarm', vmin=400, vmax=1200)
plt.title('年齢別平均年収 by 会社')
plt.xlabel('年齢層')
plt.ylabel('会社')
plt.show()
# Out:
# c:\Users\100ca\miniconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val
# 5          638.0         740.0         722.0         863.0         778.0
# 46         765.0         785.0           NaN           NaN           NaN
# 9          619.0         709.0         719.0         904.0         910.0
# 6          843.0         864.0           NaN           NaN        1119.0
# 12         525.0         854.0         915.0           NaN           NaN
# 28         615.0           NaN           NaN           NaN           NaN
# 18         681.0           NaN           NaN           NaN           NaN
# 11         749.0         927.0         863.0        1040.0           NaN
# 31           NaN           NaN           NaN           NaN           NaN
# 32           NaN         500.0           NaN           NaN           NaN
# 3          780.0           NaN        1056.0           NaN           NaN
# 64         710.0         747.0         896.0         820.0         995.0
# 15         853.0         709.0         584.0           NaN        1043.0
# 45           NaN           NaN           NaN           NaN           NaN
# 25         639.0         664.0           NaN         810.0           NaN
# 33         602.0           NaN           NaN           NaN           NaN
# 65         726.0         787.0         829.0         825.0        1059.0
# 16         809.0         817.0           NaN        1085.0           NaN
# 36         706.0         706.0         897.0         690.0        1026.0
# 4          778.0         855.0         843.0        1086.0         936.0
# 24         729.0         762.0         811.0         733.0         723.0
# 13         614.0         769.0           NaN         911.0         890.0
# 26         655.0         610.0         649.0         805.0           NaN
# 30         612.0         815.0           NaN           NaN           NaN
# 29         610.0         699.0         867.0           NaN           NaN
# 48         540.0           NaN           NaN           NaN           NaN
# 23           NaN           NaN           NaN           NaN           NaN
# 19           NaN           NaN           NaN           NaN           NaN
# 22         713.0         730.0           NaN         974.0         943.0
# 66           NaN         720.0           NaN           NaN           NaN
# 39           NaN           NaN           NaN           NaN           NaN
# 37         629.0         687.0         802.0           NaN           NaN
# 57         623.0           NaN           NaN           NaN           NaN
# 49         522.0           NaN           NaN           NaN           NaN
# 10         743.0         765.0         859.0           NaN         783.0
# 17         649.0         683.0         774.0         810.0           NaN
# 53         700.0         622.0           NaN           NaN           NaN
# 44         646.0           NaN           NaN           NaN         725.0
# 40         600.0         703.0         690.0           NaN           NaN
# 41         647.0           NaN           NaN           NaN           NaN
# 42           NaN           NaN           NaN           NaN           NaN
# 34         599.0         688.0         738.0           NaN           NaN
# 43         665.0         620.0         699.0           NaN           NaN
# 52           NaN           NaN           NaN           NaN           NaN
# 56         595.0         606.0         614.0           NaN           NaN
# 38         613.0           NaN           NaN           NaN           NaN
# 55         555.0           NaN           NaN           NaN           NaN
# 51         606.0         678.0         700.0           NaN           NaN
#
#     salary_60_up
# 0            NaN
# 2         1224.0
# 5          767.0
# 46           NaN
# 9         1098.0
# 6            NaN
# 12           NaN
# 28           NaN
# 18           NaN
# 11           NaN
# 31           NaN
# 32           NaN
# 3            NaN
# 64         939.0
# 15           NaN
# 45           NaN
# 25           NaN
# 33           NaN
# 65           NaN
# 16           NaN
# 36         850.0
# 4         1123.0
# 24         693.0
# 13           NaN
# 26         825.0
# 30           NaN
# 29           NaN
# 48           NaN
# 23           NaN
# 19           NaN
# 22           NaN
# 66           NaN
# 39           NaN
# 37           NaN
# 57           NaN
# 49           NaN
# 10           NaN
# 17           NaN
# 53           NaN
# 44           NaN
# 40           NaN
# 41         440.0
# 42           NaN
# 34           NaN
# 43           NaN
# 52           NaN
# 56           NaN
# 38           NaN
# 55           NaN
# 51           NaN

# %%
df.describe()
# Out:
#            salary   overtime  salary_25_29  salary_30_34  salary_35_39  \
# count   66.000000  66.000000     61.000000     57.000000     47.000000
# mean   601.075758  29.893939    481.442623    566.614035    654.297872
# std    101.191260   5.727474     65.563589     75.515314     87.476932
# min    367.000000  17.000000    359.000000    382.000000    450.000000
# 25%    533.500000  26.000000    440.000000    519.000000    607.500000
# 50%    587.000000  29.000000    472.000000    550.000000    638.000000
# 75%    660.500000  34.000000    513.000000    613.000000    711.500000
# max    940.000000  46.000000    697.000000    719.000000    853.000000
#
#        salary_40_44  salary_45_49  salary_50_54  salary_55_59  salary_60_up
# count     36.000000     26.000000     18.000000     15.000000     11.000000
# mean     730.527778    798.115385    870.444444    928.666667    888.909091
# std       94.791647    148.142992    119.624030    136.250644    217.840517
# min      500.000000    584.000000    690.000000    723.000000    440.000000
# 25%      681.750000    704.750000    806.250000    821.000000    796.000000
# 50%      725.000000    780.500000    844.000000    936.000000    906.000000
# 75%      785.500000    862.000000    932.000000   1034.500000   1018.500000
# max      927.000000   1304.000000   1086.000000   1141.000000   1224.000000

# %%
# Import pandas library
import pandas as pd

# Assuming 'df' is your DataFrame
pd.set_option('display.max_rows', 100)  # Set the maximum number of rows to display
pd.options.display.max_colwidth = None   # Disable column width truncation

# Display the first 100 rows of the 'company' column
df[['company']].head(100)
# Out:
#                        company
# 3                 東京エレクトロン株式会社
# 2                  ソニーグループ株式会社
# 4           パナソニックホールディングス株式会社
# 0                     株式会社ディスコ
# 1   株式会社SCREENセミコンダクターソリューションズ
# 5             ルネサスエレクトロニクス株式会社
# 6                      旭化成株式会社
# 64                     富士通株式会社
# 7                    日本板硝子株式会社
# 8                    ウシオ電機株式会社
# 9                     オムロン株式会社
# 10                     株式会社ニコン
# 11                    日東電工株式会社
# 65                    キヤノン株式会社
# 46                    三菱電機株式会社
# 12         アプライドマテリアルズジャパン株式会社
# 13                住友ベークライト株式会社
# 14                    ホシデン株式会社
# 15                    住友化学株式会社
# 16                  住友電気工業株式会社
# 17                   株式会社アルバック
# 18                  株式会社日立ハイテク
# 19                  日本電気硝子株式会社
# 36                    富士電機株式会社
# 22                  日本特殊陶業株式会社
# 21            株式会社ニューフレアテクノロジー
# 23              東レエンジニアリング株式会社
# 24                セイコーエプソン株式会社
# 25                    イビデン株式会社
# 26                   大日本印刷株式会社
# 27                    シャープ株式会社
# 28                   株式会社荏原製作所
# 29                     京セラ株式会社
# 30                  ヤマハ発動機株式会社
# 31                  信越化学工業株式会社
# 32                    株式会社東京精密
# 33                 浜松ホトニクス株式会社
# 34                 スタンレー電気株式会社
# 35                 マブチモーター株式会社
# 37                    豊田合成株式会社
# 38                 三菱マテリアル株式会社
# 39                  新光電気工業株式会社
# 40                     ローム株式会社
# 66                     デンカ株式会社
# 43                 ミネベアミツミ株式会社
# 41                    アズビル株式会社
# 42                    日本電子株式会社
# 44                  古河電気工業株式会社
# 45                   ダイトロン株式会社
# 48                    日新電機株式会社
# 47                   アイカ工業株式会社
# 49                  サンケン電気株式会社
# 50                    TOWA株式会社
# 51                     CKD株式会社
# 52               芝浦メカトロニクス株式会社
# 53                日本航空電子工業株式会社
# 54                キヤノンアネルバ株式会社
# 55                  シチズン時計株式会社
# 56               アルプスアルパイン株式会社
# 57                   ヒロセ電機株式会社
# 58                  住友精密工業株式会社
# 59                  日本ケミコン株式会社
# 61               キヤノンマシナリー株式会社
# 62                    太陽誘電株式会社
# 63                    ニチコン株式会社
# 67                   株式会社高田工業所
